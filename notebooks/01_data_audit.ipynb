# %% [markdown]
# # Audit du corpus
#
# Ce notebook lance l'audit agrégé du corpus local sans afficher ni exporter le texte brut des reports.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from trip_reports.audit import write_audit_outputs

csv_path = PROJECT_ROOT / 'data' / 'badtrip_reports_by_substance.csv'
output_dir = PROJECT_ROOT / 'outputs' / 'tables'
audit = write_audit_outputs(csv_path, output_dir)

audit

# %%
import csv

with (output_dir / 'corpus_audit_summary.csv').open() as f:
    for row in csv.reader(f):
        print(row)
